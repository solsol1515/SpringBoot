# %% [markdown]
# ## 1. Series 의 plot()

# %%
# %matplotlib inline

# %%
from pandas import Series

# %%
# 판다스 그래프 : Series의 plot() 
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
s

s.plot(kind='bar');

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %%
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])

splot = s.plot(kind='bar');
splot.set_xlabel('데이터')
splot.set_ylabel('값')
splot.set_title('샘플데이터')
# Out:
# Text(0.5, 1.0, '샘플데이터')

# %% [markdown]
# ## 2. DataFrame 그래프

# %%
from pandas import DataFrame
import numpy as np

# 데이타프레임에서 시각화 작업
df=DataFrame(np.random.randn(10, 4),    # 난수 10개를 4번
             columns=['level','step','cnt','temp'], 
             index=np.arange(0,100,10))     # np.arange(0,100,10)

df
# Out:
#        level      step       cnt      temp
# 0  -0.075685 -1.584942  0.804389  0.928480
# 10 -1.040267 -0.386804  0.363484  0.093896
# 20 -0.577367 -0.031057  0.631628  0.035221
# 30 -0.044651 -0.530948  1.330265 -0.534223
# 40  1.132521  0.782555 -0.047771  1.560481
# 50 -0.551260  1.102087 -0.397860  0.250405
# 60  1.111673 -0.747805  1.263348  0.351066
# 70  1.044711 -0.246583  0.418262  1.734447
# 80  2.787450  1.985447  0.045572  2.424890
# 90 -0.042315 -0.427349  0.909617  0.293418

# %%
df.plot()
df.plot(kind='bar')
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# [참고] 데이타사이언스스쿨 > Pandas의 시각화 기능
#
# https://datascienceschool.net/view-notebook/372443a5d90a46429c6459bba8b4342c/
